# %% [markdown]
# # Project Title: Segmentation to understand where most accidents happen
#
# # **1. Project Objectives | Problem Statements**
# #### 1.1. Segmentation of areas where most accidents happen using Unsupervised Machine Learning Clustering Algorithms : KMeans
# #### 1.2. Identification of Appropriate Number of Segments or Clusters
# #### 1.3. Determination of Segment or Cluster Characteristics
#
#
#
# # **2. Description of Data**
# ## **2.1. Data Source, Size, Shape**
# ### **2.1.1. Data Source (Website Link)**
# #### Here is the Kaggle link to the dataset : https://www.kaggle.com/datasets/nextmillionaire/car-accident-dataset
#
# ###**2.1.2. Data Size**
# #### Memory usage (KB): 50526.94921875
# #### Memory usage (MB): 49.34272384643555
#
# ### **2.1.3. Data Shape**
# #### Number of rows: 307973
# #### Number of columns: 21
#
# ## **2.2. Description of Variables**
# ### **2.2.1. Index Variable(s)**
# ##### Index variables are 'Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control','Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions','Local_Authority_(District) , 'Carriageway_Hazards', 'Longitude',  'Number_of_Casualties', 'Number_of_Vehicles', 'Police_        Force','Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time','Urban_or_Rural_Area', 'Weather_Conditions' and 'Vehicle_Type'
#
#
# ### **2.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
# ##### Categorical Variables are :‘Accident_Index', 'Accident Date','Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'
#
# #### **2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type**
# ###### Nominal Columns are : 'Accident_Index', 'Accident Date', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'
#
# #### **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
# ###### Ordinal Columns are : ['Day_of_Week']
#
# ###**2.2.3. Non-Categorical Variables or Features**
# ###### Non-Categorical Columns are : 'Latitude', 'Longitude','Number_of_Casualties', 'Number_of_Vehicles', 'Speed_limit'
#
#
# ## **2.3. Descriptive Statistics**
# ### **2.3.1. Descriptive Statistics: Categorical Variables or Features**
# #### **2.3.1.1. Count | Frequency Statistics**
# ##### Accident Severity: Mild injuries accounted for 67% of all incidents, with serious injuries making up 10% and fatalities making up 1%.  Daytime crashes accounted for the majority of accidents (68%), with darkness and illuminated lights coming in second and third, respectively, at 18% and 5%. **Birmingham** has the most accidents (6,165), while smaller districts like Berwick-upon-Tweed have the fewest (13). The data includes a wide range of areas. The most common road surface conditions were dry roads (63%), followed by wet/damp conditions (24%). Most accidents occur on **single carriageway roads** (69%), with dual carriageways coming in second (14%). A minor fraction consists of slip roads, roundabouts, and one-way streets. **Urban areas** accounted for 63% of all accidents, with rural areas making up the remaining 37%.**Cars** account for 73% of all vehicles involved in accidents, with vans coming in second with 5%.
#
#
# ####**2.3.1.2. Proportion (Relative Frequency) Statistics**
# ##### About 85% of accidents caused only minor injuries, with serious injuries coming in second at 13% and fatalities at a significantly lower percentage at 1%. Daytime incidents accounted for 74% of all accidents, whereas accidents involving lighted lights and darkness only made for 19%. Extreme darkness with no light and unclear lighting were far less common. Mostly all of the statistics have already been explained.
#
#
# ###**2.3.2. Descriptive Statistics: Non-Categorical Variables or Features**
# #### **2.3.2.1. Measures of Central Tendency**
# ##### The mean geographic coordinates of the accidents are represented by the mean latitude (52.49) and mean longitude (-1.37). For both latitude and longitude, the occurrence of a mode raises the possibility that accidents are concentrated in particular geographic regions. On average, there are slightly more casualties per accident, as indicated by the mean (1.36). The average (1.83) indicates that almost two cars are typically involved in each accident. The median is in line with the mean, indicating that two vehicles are involved in the majority of collisions. The fact that two-vehicle accidents are the most common is further supported by mode.The total average is provided by the mean speed limit of 38.87. According to the median (30.0), half of the accidents happened on routes where the posted speed limit was 30 mph or below. The mode (30.0) indicates that the speed restriction zone where accidents occur most frequently is 30 mph.
#
#
#
# ####**2.3.2.2. Measures of Dispersion**
# ##### The range, which is around 10.68 degrees for latitude and 9.28 degrees for longitude, shows how much of the accident data's geographic coverage there is. A substantial dispersion of locations around the average latitude and longitude is shown by the variance and standard deviation, which are both approximately 1.34. In comparison to the range, the IQR (around 2 degrees) is rather modest, indicating that a sizable fraction of accidents are concentrated around the median values, which may indicate potential hotspots in terms of geography.The range (31 cars and 47 casualties) illustrates how different each accident is in terms of the number of vehicles and individuals involved. The Standard Deviation (around 0.82 and 0.71, respectively) and lesser variance (about 0.66 for casualties and 0.50 for cars) suggest that most accidents have a number of casualties and vehicles that are near to average. The range (60 mph) indicates a significant difference in the data's speed limitations. A broader distribution of speed limits is indicated by a much higher variance (around 197) and Standard Deviation (about 14.03) when compared to other variables. The middle half of the data is represented by the IQR (20 mph), which shows that a sizable percentage of accidents happen on roads where the speed restriction is between 20 and 30 mph from the median value.
#
#
# ####**2.3.2.3. Correlation Statistics (with Test of Correlation)**
# ##### Latitude and longitude: There is a weak negative connection (-0.3656) between the two, which suggests that as latitude rises, there may be a tiny tendency for accidents to occur southwest. The number of casualties has a weakly positive association (0.2345) with the number of vehicles. There is a little correlation between the number of casualties in an accident and the number of vehicles involved. There may be a modest increase in casualties from accidents in locations with higher speed restrictions, although the relationship is weak. There is limited evidence to support the theory that locations with somewhat higher speed restrictions may see an increase in vehicle-related accidents.

# %% [markdown]
# # **3.  Analysis of Data**
# ## **3.1. Data Pre-Processing**
# ### **3.1.1. Missing Data Statistics and Treatment**
# #### **3.1.1.1.1. Missing Data Statistics: Records**
# ##### The number of non-null values (i.e., entries containing data) for each column is shown in the table. A smaller fraction of the data is missing from columns like "Road_Surface_Conditions" (217 missing values) and "Carriageway_Hazards" (3 missing values), whereas a larger amount is missing from columns like "Road_Type" (1534 missing values).
#
# #### **3.1.1.1.2. Missing Data Treatment: Records**
# ##### **3.1.1.1.2.1. Removal of Records with More Than 50% Missing Data**
# ######For the purpose of removing columns, a 50% missing values threshold—that is, more than half of the rows in a column with missing data—was set. No columns in the dataset exceeded this threshold, according to analysis. As a result, no columns were eliminated because of missing data.
#
# #### **3.1.1.2.1. Missing Data Statistics: Categorical Variables or Features Minimal Values Missing**
#  ###### There are just three missing entries in Carriageway_Hazards, or 0.00% of the total data. This implies that the dataset for this variable is complete. Weather_Conditions column has a reasonably low amount of missing data (6057 entries, or 1.97%), while not being fully comprehensive. This could out to be a reasonable quantity, contingent upon the area of study.Road_Surface_Conditions has 317 missing records, or 0.10% of the total data. This is a significant number of missing entries. To determine the cause of the missing data, this may require additional research. Fifteen hundred and four records, or 0.50% of the dataset, are missing from Road_Type: column. This substantial lack of information necessitates cautious thought.
#
# #####**3.1.1.2.2.1. Removal of Variables or Features with More Than 50% Missing Data**
# ###### Again we have already checked for this aspect. There is no record where more than 50% data is missing and thus no data is treated
#
# #####**3.1.1.2.2.2. Imputation of Missing Data using Descriptive Statistics: Mode**
# ###### The code for Simple imputer has been run in order to fill the missing values.
#
# ####**3.1.1.3.1. Missing Data Statistics: Non-Categorical Variables or Features**
# ###### No missing data found in Non categorical Variables
#
# ####**3.1.1.3.2. Missing Data Treatment: Non-Categorical Variables or Features**
# #####**3.1.1.3.2.1. Removal of Variables or Features with More Than 50% Missing Data**
# ###### No missing data was found in non Categorial variables. Thus, no need for removal of any kind of data.
# #####**3.1.1.3.2.2. Imputation of Missing Data using Descriptive Statistics: Mean**
# ###### There was no missing data but still code for imputing was ran & outcome was no change in dataset.
#
# ### **3.1.2. Numerical Encoding of Categorical Variables or Features (Encoding Schema - Alphanumeric Order)**
# ###### Used label encoding for variables such as 'Junction_Control','Junction_Detail','Light_Conditions','Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force','Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area','Weather_Conditions', 'Vehicle_Type'. And ordinal encoding for 'Day_of_Week', 'Accident_Severity'
#
# ### **3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)**
# #### **3.1.3.1.1. Outlier Statistics: Non-Categorical Variables or Features**
# ###### The code used the Interquartile Range (IQR) approach to find outliers in the numerical columns. Outliers were defined as values that are significantly outside of 1.5 times the IQR, either above or below the third quartile. The code provided a thorough overview of the data distribution and identified potential anomalies by computing statistics like mean, standard deviation, quartiles, and the number of outliers. No outliers were found in speed Limit amongst non categorical variables.
#
# ####**3.1.3.1.2. Outlier Treatment: Non-Categorical Variables or Features**
# #####**3.1.3.1.2.1. Normalization using Min-Max Scaler**
# ###### The outliers were treated in the following columns : 'Latitude', 'Longitude', 'Number_of_Casualties' and 'Number_of_Vehicles'.

# %% [markdown]
# ##**3.2. Data Analysis**
# ###**3.2.1.1. Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance
# ##### Here two different clustering are done with different set of variables to find appropriate areas where most accidents happen. First, variables taken are 'Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code'. Second, the variables taken are 'Road_Type_code','Urban_or_Rural_Area_code', 'Accident_Severity_code','Light_Conditions_code'.
#
# ####**3.2.2.1.1.  Clustering Model Performance Evaluation: Silhouette Score | Davies-Bouldin Score (Base Model: K-Mean)**
# ##### **For first clustering**
# ##### k=2 Silhouette Score: 0.02546637355129478,Davies-Bouldin Score: 42.3738220531719
# ##### k=3 Silhouette Score: 0.0005741600005830396, Davies-Bouldin Score: 45.85307471096089
# ##### k=4 Silhouette Score: 0.021430079094563816, Davies-Bouldin Score: 25.51007321005486
# ##### k=5 Silhouette Score: -0.025800628119926877, Davies-Bouldin Score: 15.324547795941722
# ###### By evaluating the db score and ss score k=2 seems to be the right number of clusters but it is trivial. Thus considering k=3 the most appropriate number of clusters.
#
# ##### **For Second Clustering**
# ##### k=2 Silhouette Score: 0.23063166138520994, Davies-Bouldin Score: 4.368843702967515
# ##### k=3 Silhouette Score: -0.005366294886769236, Davies-Bouldin Score: 16.650587110763784
# ##### k=4 Silhouette Score: -0.017176282224383874, Davies-Bouldin Score: 21.195585822305148
# ###### By evaluating the db score and ss score k=3 seems to be the right number of clusters.
#
#
# ####**3.2.2.1.2. Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Mean)**
# ##### **For first clustering**
# ##### For k = 3, maximum memory usage: 1011.86328125 MB, execution time: 1.728098 seconds
# ##### **For second clustering**
# ##### For k = 3, maximum memory usage: 1019.7734375 MB, execution time: 1.725788 seconds
#
# ###**3.2.2.1. Cluster Analysis: Base Model (K-Means)**
# ####**3.2.3.1.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
# ##### The p value for each variable in both of the clusters is 0, indicating that each variable used here distinguihes the clusters significantly.
# ####**3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
# ##### Since all the variables are categorical thus, ANOVA is not required.

# %% [markdown]
# #**4. Results | Observations**
# ##**4.1. Appropriate Number of Segments**
# The appropriate number of cluster for both of the clustering is 3. This is strictly based on the observed db score and ss score.
# ##**4.2. Cluster Size**
# The cluster sizes for first clustering are given below:
#
# Cluster sizes for k=3: [55143, 209078, 43752]
#
#
# The cluster sizes for second clustering are given below:
#
#
# Cluster sizes for k=3: [40378, 203646, 63949]
#
# ##**4.3. Cluster Analysis**
# ###**4.3.1. Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
# For the first clustering all the three variable significantly distinguish the clusters. The variables are Light_Conditions_code',  'Weather_Conditions_code', 'Road_Surface_Conditions_code'.
# For second clustering again the four variables used significanty distinguish the clusters. These variables namely are 'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time','Urban_or_Rural_Area', 'Weather_Conditions' and 'Vehicle_Type'
# ###**4.3.2. Non-Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
# Non categorical variables were not used for clustering thus not involved in ananlysis.
# ##**4. Clustering Model Performance: Time & Memory Statistics**
# **For first clustering**
#
# For k = 3, maximum memory usage: 1011.86328125 MB, execution time: 1.728098 seconds
#
# **For second clustering**
#
# For k = 3, maximum memory usage: 1019.7734375 MB, execution time: 1.725788 seconds

# %% [markdown]
# ##**5.1. Appropriate Number of Clusters**
# The appropriate number of cluters in each clustering is 3.
# ##**5.2. Identification of a ‘Niche’ Cluster**
# **For first clustering**
#
# The smallest cluster does not indicate any niche area where accidents happen but a mix of all the possible conditions.
#
# **For Second Clustering**
#
# Least number of accidents are non fatal and occur during adequate visibility
#
# ##**5.3. Segment | Cluster - (Heterogeneous) Identity | Nomenclature**
# #####**For First Clustering**
# ##### Cluster 0 (Blue): car crashes throughout the day, mostly in urban and rural areas, with a greater likelihood of non-fatal injuries.Cluster 1 (Green)is Predominantly daytime bus accidents in both urban and rural locations, with a propensity for non-fatal injuries. Cluster 2 (Red) has a variety of vehicle types in both urban and rural settings, with varying lighting conditions and a possible increased risk of both non-fatal and deadly accidents.
#
# ##### The second cluster has the biggest size indicating that most accidents that happen are daytime bus accidents.
#
# #####**For Second clustering**
# ##### Cluster 0 (Blue): Mostly non-fatal accidents (Slight/Serious) in a variety of weather and road conditions with adequate visibility (daytime/lit darkness).Similar to Cluster 0, Cluster 1 (Green) sees a higher frequency of non-fatal accidents (Slight/Serious) during the daytime under a range of weather and road conditions.Cluster 2 (Red): May have a greater chance of deadly collisions; may happen in a variety of weather and road circumstances, as well as in different lighting conditions (such as low visibility).
#
# ##### Again size of second cluster is the biggest indicating most non fatal accidents happening against a range of weather and road conditions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
import datetime as dt

import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import StandardScaler , RobustScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets

# %%
df = pd.read_csv('Road Accident Data.csv')

# %%
df
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001    01-01-2021    Thursday      Give way or uncontrolled
# 1       200901BS70002    05-01-2021      Monday      Give way or uncontrolled
# 2       200901BS70003    04-01-2021      Sunday      Give way or uncontrolled
# 3       200901BS70004    05-01-2021      Monday           Auto traffic signal
# 4       200901BS70005    06-01-2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760    18-02-2022    Thursday  Data missing or out of range
# 307969  201091NM01881    21-02-2022      Sunday  Data missing or out of range
# 307970  201091NM01935    23-02-2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964    23-02-2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142    28-02-2022      Sunday      Give way or uncontrolled
#
# ...

# %% [markdown]
# # Description Of Data
# ## 2.1 Data Source, Size, Shape

# %% [markdown]
# ### 2.1.1
#
# *italicized text*

# %% [markdown]
# ### 2.1.2 Data Size

# %%
# Import pandas library
import pandas as pd

# Assuming df is your DataFrame
# If your DataFrame is loaded from a file, you might need to load it first

# Check the memory usage of the DataFrame in bytes
memory_bytes = df.memory_usage().sum()

# Convert bytes to kilobytes (KB), megabytes (MB), gigabytes (GB), etc.
memory_kb = memory_bytes / 1024
memory_mb = memory_kb / 1024
memory_gb = memory_mb / 1024

# Print the memory usage of the DataFrame in various units
print("Memory usage (KB):", memory_kb)
print("Memory usage (MB):", memory_mb)
print("Memory usage (GB):", memory_gb)
# Out:
# Memory usage (KB): 50526.9453125
# Memory usage (MB): 49.34272003173828
# Memory usage (GB): 0.048186250030994415

# %% [markdown]
# ### 2.1.3 Data Shape

# %%
# Import pandas library
import pandas as pd

# Assuming df is your DataFrame
# If your DataFrame is loaded from a file, you might need to load it first

# Check the size of the DataFrame
data_size = df.shape

# Print the size of the DataFrame
print("Number of rows:", data_size[0])
print("Number of columns:", data_size[1])
# Out:
# Number of rows: 307973
# Number of columns: 21

# %% [markdown]
# ## 2.2 Description Of Variables

# %% [markdown]
# ### 2.2.1 Index Variables

# %%
# Displaying the columns and their descriptions
print("Column Descriptions:")
print(df.columns)
# Out:
# Column Descriptions:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %% [markdown]
# ### 2.2.2 Variables with Categories

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# Printing the list of categorical columns
print("Categorical Columns:")
print(categorical_columns)
# Out:
# Categorical Columns:
# ['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']

# %% [markdown]
# #### 2.2.2.1 Nominal Categories
# **bold text**

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# Removing columns that might be ordinal (ordered categorical)
ordinal_columns = ['Day_of_Week']  # Add other columns if known
nominal_columns = [col for col in categorical_columns if col not in ordinal_columns]

# Printing the list of nominal columns
print("Nominal Columns:")
print(nominal_columns)
# Out:
# Nominal Columns:
# ['Accident_Index', 'Accident Date', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']

# %% [markdown]
# #### 2.2.2.2 Ordinal Variables

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# List of columns that are known to be ordinal
ordinal_columns = ['Day_of_Week']  # Add other columns if known

# Printing the list of ordinal columns
print("Ordinal Columns:")
print(ordinal_columns)
# Out:
# Ordinal Columns:
# ['Day_of_Week']

# %% [markdown]
# ### 2.2.3 Non Categorical Variables

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with non-object data type (typically numerical)
non_categorical_columns = df.select_dtypes(exclude=['object']).columns.tolist()

# Printing the list of non-categorical columns
print("Non-Categorical Columns:")
print(non_categorical_columns)
# Out:
# Non-Categorical Columns:
# ['Latitude', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Speed_limit']

# %% [markdown]
# ## 2.3 Descriptive Statistics
# ### 2.3.1 For Categorical Variables
# #### 2.3.1.1 Frequency Statistics

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# Iterating over each categorical column to find frequency statistics
for column in categorical_columns:
    print("Frequency statistics for column:", column)
    print(df[column].value_counts())
    print("\n")
# Out:
# Frequency statistics for column: Accident_Index
# 2.01E+12         110304
# 2.01E+46              3
# 2.01E+307             2
# 2.01E+199             2
# 2.01E+48              2
#                   ...
# 200934NC22759         1
# 200934NC22829         1
# 200934NC22889         1
# 200934NC22899         1
# 201091NM02142         1
# Name: Accident_Index, Length: 197644, dtype: int64
#
#
# Frequency statistics for column: Accident Date
# 13-11-2021    692
# 11-02-2021    685
# 06-10-2021    680
# 04-12-2021    667
# 12-11-2021    659
#              ...
# 28-12-2022    181
# 27-12-2022    179
# 30-12-2022    171
# 25-12-2022    145
# 10-01-2022    123
# Name: Accident Date, Length: 730, dtype: int64
#
#
# Frequency statistics for column: Day_of_Week
# Friday       50529
# Tuesday      46386
# Wednesday    46381
# Thursday     45649
# Monday       43918
# Saturday     41566
# Sunday       33544
# Name: Day_of_Week, dtype: int64
#
#
# Frequency statistics for column: Junction_Control
# ...

# %% [markdown]
# #### 2.3.1.2 Proportion (Relative Frequency)

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# Iterating over each categorical column to find proportion statistics
for column in categorical_columns:
    print("Proportion statistics for column:", column)
    # Calculating value counts
    value_counts = df[column].value_counts()
    # Calculating proportions
    proportions = value_counts / len(df)
    print(proportions)
    print("\n")
# Out:
# Proportion statistics for column: Accident_Index
# 2.01E+12         0.358161
# 2.01E+46         0.000010
# 2.01E+307        0.000006
# 2.01E+199        0.000006
# 2.01E+48         0.000006
#                    ...
# 200934NC22759    0.000003
# 200934NC22829    0.000003
# 200934NC22889    0.000003
# 200934NC22899    0.000003
# 201091NM02142    0.000003
# Name: Accident_Index, Length: 197644, dtype: float64
#
#
# Proportion statistics for column: Accident Date
# 13-11-2021    0.002247
# 11-02-2021    0.002224
# 06-10-2021    0.002208
# 04-12-2021    0.002166
# 12-11-2021    0.002140
#                 ...
# 28-12-2022    0.000588
# 27-12-2022    0.000581
# 30-12-2022    0.000555
# 25-12-2022    0.000471
# 10-01-2022    0.000399
# Name: Accident Date, Length: 730, dtype: float64
#
#
# Proportion statistics for column: Day_of_Week
# Friday       0.164070
# Tuesday      0.150617
# Wednesday    0.150601
# Thursday     0.148224
# Monday       0.142603
# Saturday     0.134966
# ...

# %% [markdown]
# ### 2.3.2 Descriptive Statistics for Non Categorical Variables
# #### 2.3.2.1 Measures of Central Tendency

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with non-object data type (typically numerical)
non_categorical_columns = df.select_dtypes(exclude=['object']).columns.tolist()

# Iterating over each non-categorical column to find measures of central tendency
for column in non_categorical_columns:
    print("Measures of central tendency for column:", column)
    # Calculating mean
    mean_value = df[column].mean()
    print("Mean:", mean_value)

    # Calculating median
    median_value = df[column].median()
    print("Median:", median_value)

    # Calculating mode
    mode_value = df[column].mode()
    print("Mode:", mode_value[0])  # Mode can be multiple, so we select the first one

    print("\n")
# Out:
# Measures of central tendency for column: Latitude
# Mean: 52.48700471916694
# Median: 52.225943
# Mode: 52.458798
#
#
# Measures of central tendency for column: Longitude
# Mean: -1.3688840968006937
# Median: -1.349258
# Mode: -1.190861
#
#
# Measures of central tendency for column: Number_of_Casualties
# Mean: 1.3568819344552931
# Median: 1.0
# Mode: 1
#
#
# Measures of central tendency for column: Number_of_Vehicles
# Mean: 1.8290629373354157
# Median: 2.0
# Mode: 2
#
#
# Measures of central tendency for column: Speed_limit
# Mean: 38.86603695778526
# Median: 30.0
# Mode: 30

# %% [markdown]
# #### 2.3.2.2 Measures Of Dispersion

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with non-object data type (typically numerical)
numerical_columns = df.select_dtypes(include=['int', 'float']).columns.tolist()

# Iterating over each numerical column to find measures of dispersion
for column in numerical_columns:
    print("Measures of dispersion for column:", column)
    # Calculating range
    data_range = df[column].max() - df[column].min()
    print("Range:", data_range)

    # Calculating variance
    data_variance = df[column].var()
    print("Variance:", data_variance)

    # Calculating standard deviation
    data_std_dev = df[column].std()
    print("Standard Deviation:", data_std_dev)

    # Calculating interquartile range (IQR)
    data_iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    print("Interquartile Range (IQR):", data_iqr)

    print("\n")
# Out:
# Measures of dispersion for column: Latitude
# Range: 10.683567000000004
# Variance: 1.7929498148538807
# Standard Deviation: 1.3390107597976504
# Interquartile Range (IQR): 1.9302690000000027
#
#
# Measures of dispersion for column: Longitude
# Range: 9.275623
# Variance: 1.8389845054656142
# Standard Deviation: 1.3560916287130507
# Interquartile Range (IQR): 2.041127
#
#
# Measures of dispersion for column: Number_of_Casualties
# Range: 47
# Variance: 0.6656225455041975
# Standard Deviation: 0.8158569393614284
# Interquartile Range (IQR): 0.0
#
#
# Measures of dispersion for column: Number_of_Vehicles
# Range: 31
# Variance: 0.5047770228237816
# Standard Deviation: 0.7104766166622105
# Interquartile Range (IQR): 1.0
#
#
# Measures of dispersion for column: Speed_limit
# Range: 60
# Variance: 196.92321408039484
# Standard Deviation: 14.03293319589297
# Interquartile Range (IQR): 20.0

# %% [markdown]
# #### 2.3.2.3 Correlation Statistics

# %%
import pandas as pd

# Assuming df is your DataFrame containing the non-categorical data
# Load your dataset into df

non_categorical_data = df[['Latitude','Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Speed_limit']]

# Summary statistics
summary_statistics = non_categorical_data.describe()
print("Summary Statistics:")
print(summary_statistics)

# Correlation matrix
correlation_matrix = non_categorical_data.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Summary Statistics:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles  \
# count  307973.000000  307973.000000         307973.000000       307973.000000
# mean       52.487005      -1.368884              1.356882            1.829063
# std         1.339011       1.356092              0.815857            0.710477
# min        49.914488      -7.516225              1.000000            1.000000
# 25%        51.485248      -2.247937              1.000000            1.000000
# 50%        52.225943      -1.349258              1.000000            2.000000
# 75%        53.415517      -0.206810              1.000000            2.000000
# max        60.598055       1.759398             48.000000           32.000000
#
#          Speed_limit
# count  307973.000000
# mean       38.866037
# std        14.032933
# min        10.000000
# 25%        30.000000
# 50%        30.000000
# 75%        50.000000
# max        70.000000
#
# Correlation Matrix:
# ...

# %% [markdown]
# # 3. Analysis Of Data
# ## 3.1 Data Pre-Processing
# ### 3.1.1. Missing Data Statistics and Treatment
# #### 3.1.1.1.1 Missing Data Statistics: Records

# %%
# Data Bifurcation
df_cat = df[['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control', 'Junction_Detail', 'Accident_Severity', 'Light_Conditions', 'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force', 'Road_Surface_Conditions', 'Road_Type', 'Time', 'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Latitude', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles', 'Speed_limit']] # Non-Categorical Data

# %%
df.info() # Dataframe Information (Provide Information on Missing Data)
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  object
#  2   Day_of_Week                 307973 non-null  object
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Latitude                    307973 non-null  float64
#  7   Light_Conditions            307973 non-null  object
#  8   Local_Authority_(District)  307973 non-null  object
#  9   Carriageway_Hazards         307970 non-null  object
#  10  Longitude                   307973 non-null  float64
#  11  Number_of_Casualties        307973 non-null  int64
#  12  Number_of_Vehicles          307973 non-null  int64
# ...

# %% [markdown]
# ##### Removal of Records with More Than 50% Missing Data

# %%
import pandas as pd

# Assuming df is your DataFrame

# Remove variables (columns) with equal to or more than 50% missing values
threshold_columns = len(df) * 0.5  # 50% threshold
df_clean_columns = df.dropna(thresh=threshold_columns, axis=1)

# Remove records (rows) with equal to or more than 50% missing values
df_clean_records = df.dropna(thresh=df.shape[1] * 0.5, axis=0)

# Example: Print the shape of the cleaned DataFrame after removing columns and records
print("Shape of DataFrame after removing columns with 50% or more missing values:", df_clean_columns.shape)
print("Shape of DataFrame after removing rows with 50% or more missing values:", df_clean_records.shape)
# Out:
# Shape of DataFrame after removing columns with 50% or more missing values: (307973, 21)
# Shape of DataFrame after removing rows with 50% or more missing values: (307973, 21)

# %% [markdown]
# #### 3.1.1.2.1 Missing Data Statistics: Categorical Variables or Features

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# Iterating over each categorical column to find missing data statistics
for column in categorical_columns:
    print("Missing data statistics for column:", column)
    missing_data_count = df[column].isnull().sum()
    total_data_count = len(df)
    missing_data_percentage = (missing_data_count / total_data_count) * 100
    print("Total Missing Values:", missing_data_count)
    print("Percentage of Missing Values: {:.2f}%".format(missing_data_percentage))
    print("\n")
# Out:
# Missing data statistics for column: Accident_Index
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Accident Date
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Day_of_Week
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Junction_Control
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Junction_Detail
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Accident_Severity
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Light_Conditions
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Local_Authority_(District)
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# ...

# %% [markdown]
# #### 3.1.1.2.2. Missing Data Treatment: Categorical Variables or Features
# ###### 3.1.1.2.2.1. Removal of Variables or Features with More Than 50% Missing Data

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with object data type (typically categorical)
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()

# List to store columns to drop
columns_to_drop = []

# Iterating over each categorical column to find columns with more than 50% missing data
for column in categorical_columns:
    missing_data_count = df[column].isnull().sum()
    total_data_count = len(df)
    missing_data_percentage = (missing_data_count / total_data_count) * 100
    if missing_data_percentage > 50:
        print("Column '{}' has more than 50% missing data ({}%)".format(column, missing_data_percentage))
        columns_to_drop.append(column)

# Dropping columns with more than 50% missing data
df.drop(columns=columns_to_drop, inplace=True)

# Print columns dropped
print("Columns dropped:", columns_to_drop)

# Optional: Print DataFrame info after dropping columns
print(df_cat.info())
# Out:
# Columns dropped: []
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  object
#  2   Day_of_Week                 307973 non-null  object
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Light_Conditions            307973 non-null  object
#  7   Local_Authority_(District)  307973 non-null  object
#  8   Carriageway_Hazards         307970 non-null  object
#  9   Police_Force                307973 non-null  object
#  10  Road_Surface_Conditions     307656 non-null  object
#  11  Road_Type                   306439 non-null  object
# ...

# %% [markdown]
# ##### 3.1.1.2.2.2. Imputation of Missing Data using Descriptive Statistics: Mode

# %%
si_cat = SimpleImputer(missing_values=np.nan, strategy='most_frequent') # Strategy = median [When Odd Number of Categories Exists]
si_cat_fit = si_cat.fit_transform(df_cat)
df_cat_mdi = pd.DataFrame(si_cat_fit, columns=df_cat.columns); df_cat_mdi # Missing Categorical Data Imputed Subset
df_cat_mdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Accident_Index              307973 non-null  object
#  1   Accident Date               307973 non-null  object
#  2   Day_of_Week                 307973 non-null  object
#  3   Junction_Control            307973 non-null  object
#  4   Junction_Detail             307973 non-null  object
#  5   Accident_Severity           307973 non-null  object
#  6   Light_Conditions            307973 non-null  object
#  7   Local_Authority_(District)  307973 non-null  object
#  8   Carriageway_Hazards         307973 non-null  object
#  9   Police_Force                307973 non-null  object
#  10  Road_Surface_Conditions     307973 non-null  object
#  11  Road_Type                   307973 non-null  object
#  12  Time                        307973 non-null  object
# ...

# %% [markdown]
# #### 3.1.1.3.1. Missing Data Statistics: Non-Categorical Variables or Features

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with non-object data type (typically numerical)
non_categorical_columns = df.select_dtypes(exclude=['object']).columns.tolist()

# Iterating over each non-categorical column to find missing data statistics
for column in non_categorical_columns:
    print("Missing data statistics for column:", column)
    missing_data_count = df[column].isnull().sum()
    total_data_count = len(df)
    missing_data_percentage = (missing_data_count / total_data_count) * 100
    print("Total Missing Values:", missing_data_count)
    print("Percentage of Missing Values: {:.2f}%".format(missing_data_percentage))
    print("\n")
# Out:
# Missing data statistics for column: Latitude
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Longitude
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Number_of_Casualties
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Number_of_Vehicles
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%
#
#
# Missing data statistics for column: Speed_limit
# Total Missing Values: 0
# Percentage of Missing Values: 0.00%

# %% [markdown]
# ##### 3.1.1.3.1. Missing Data Statistics: Non-Categorical Variables or Features
# #### 3.1.1.3.2. Missing Data Treatment: Non-Categorical Variables or Features
# ##### 3.1.1.3.2.1. Removal of Variables or Features with More Than 50% Missing Data
# ##### 3.1.1.3.2.2. Imputation of Missing Data using Descriptive Statistics: Mean | Median

# %%
si_noncat = SimpleImputer(missing_values=np.nan, strategy='median') # Other Strategy : mean | median | most_frequent | constant
si_noncat_fit = si_noncat.fit_transform(df_noncat)
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat.columns); df_noncat_mdi_si # Missing Non-Categorical Data Imputed Subset using Simple Imputer
df_noncat_mdi_si.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Latitude              307973 non-null  float64
#  1   Longitude             307973 non-null  float64
#  2   Number_of_Casualties  307973 non-null  float64
#  3   Number_of_Vehicles    307973 non-null  float64
#  4   Speed_limit           307973 non-null  float64
# dtypes: float64(5)
# memory usage: 11.7 MB

# %% [markdown]
# ### 3.1.2. Numerical Encoding of Categorical Variables or Features

# %%
df_cat_mdi_code = df_cat_mdi.copy()

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Create a LabelEncoder instance
le = LabelEncoder()

# List of categorical variables to be encoded
categorical_variables = ['Junction_Control', 'Junction_Detail', 'Light_Conditions',
                         'Local_Authority_(District)', 'Carriageway_Hazards', 'Police_Force',
                         'Road_Surface_Conditions', 'Road_Type', 'Urban_or_Rural_Area',
                         'Weather_Conditions', 'Vehicle_Type']

# Initialize an empty DataFrame to store the encoded values
encoded_df = pd.DataFrame()

# Loop through each categorical variable and encode it
for var in categorical_variables:
    # Fit and transform the variable using LabelEncoder
    encoded_var = le.fit_transform(df_cat_mdi_code[var])

    # Create a DataFrame for the encoded variable
    encoded_var_df = pd.DataFrame(encoded_var, columns=[f'{var}_code'])

    # Concatenate the encoded variable DataFrame with the main DataFrame
    encoded_df = pd.concat([encoded_df, encoded_var_df], axis=1)

# Concatenate the original DataFrame with the encoded variables
df_cat_mdt_code_le = pd.concat([df_cat_mdi_code, encoded_df], axis=1)

# Now df_cat_mdt_code_le contains the original DataFrame with the categorical variables encoded

# %%
print(df_cat_mdt_code_le)
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001    01-01-2021    Thursday      Give way or uncontrolled
# 1       200901BS70002    05-01-2021      Monday      Give way or uncontrolled
# 2       200901BS70003    04-01-2021      Sunday      Give way or uncontrolled
# 3       200901BS70004    05-01-2021      Monday           Auto traffic signal
# 4       200901BS70005    06-01-2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760    18-02-2022    Thursday  Data missing or out of range
# 307969  201091NM01881    21-02-2022      Sunday  Data missing or out of range
# 307970  201091NM01935    23-02-2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964    23-02-2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142    28-02-2022      Sunday      Give way or uncontrolled
#
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd

# Create an OrdinalEncoder instance
oe = OrdinalEncoder()

# List of categorical variables to be encoded
categorical_variables = ['Day_of_Week', 'Accident_Severity']

# Fit and transform the categorical variables using OrdinalEncoder
oe_fit = oe.fit_transform(df_cat_mdi_code[categorical_variables])

# Create a DataFrame for the encoded variables
encoded_variables = [var + '_code' for var in categorical_variables]
df_cat_code_oe = pd.DataFrame(oe_fit, columns=encoded_variables)

# Concatenate the original DataFrame with the encoded variables
df_cat_mdi_code_oe = pd.concat([df_cat_mdi_code, df_cat_code_oe], axis=1)

# Now df_cat_mdi_code_oe contains the original DataFrame with the categorical variables encoded

# %%
df_cat_mdi_code_oe
# Out:
#        Accident_Index Accident Date Day_of_Week              Junction_Control  \
# 0       200901BS70001    01-01-2021    Thursday      Give way or uncontrolled
# 1       200901BS70002    05-01-2021      Monday      Give way or uncontrolled
# 2       200901BS70003    04-01-2021      Sunday      Give way or uncontrolled
# 3       200901BS70004    05-01-2021      Monday           Auto traffic signal
# 4       200901BS70005    06-01-2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968  201091NM01760    18-02-2022    Thursday  Data missing or out of range
# 307969  201091NM01881    21-02-2022      Sunday  Data missing or out of range
# 307970  201091NM01935    23-02-2022     Tuesday      Give way or uncontrolled
# 307971  201091NM01964    23-02-2022     Tuesday      Give way or uncontrolled
# 307972  201091NM02142    28-02-2022      Sunday      Give way or uncontrolled
#
# ...

# %% [markdown]
# ## 3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)
# ### 3.1.3.1.1. Outlier Statistics: Non-Categorical Variables or Features

# %%
# Importing necessary library
import pandas as pd

# Assuming df is your DataFrame

# Selecting columns with non-object data type (typically numerical)
non_categorical_columns = df.select_dtypes(exclude=['object']).columns.tolist()

# Iterating over each non-categorical column to find outlier statistics
for column in non_categorical_columns:
    print("Outlier statistics for column:", column)
    # Calculating mean
    mean_value = df[column].mean()
    # Calculating standard deviation
    std_value = df[column].std()
    # Calculating quartiles
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    # Calculating lower and upper bounds for outliers detection
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    # Finding outliers
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]

    # Printing outlier statistics
    print("Mean:", mean_value)
    print("Standard Deviation:", std_value)
    print("Q1:", q1)
    print("Q3:", q3)
    print("IQR:", iqr)
    print("Lower Bound (Outlier):", lower_bound)
    print("Upper Bound (Outlier):", upper_bound)
    print("Number of Outliers:", len(outliers))
    print("\n")
# Out:
# Outlier statistics for column: Latitude
# Mean: 52.48700471916694
# Standard Deviation: 1.3390107597976504
# Q1: 51.485248
# Q3: 53.415517
# IQR: 1.9302690000000027
# Lower Bound (Outlier): 48.5898445
# Upper Bound (Outlier): 56.31092050000001
# Number of Outliers: 3335
#
#
# Outlier statistics for column: Longitude
# Mean: -1.3688840968006937
# Standard Deviation: 1.3560916287130507
# Q1: -2.247937
# Q3: -0.20681
# IQR: 2.041127
# Lower Bound (Outlier): -5.3096274999999995
# Upper Bound (Outlier): 2.8548805
# Number of Outliers: 655
#
#
# Outlier statistics for column: Number_of_Casualties
# Mean: 1.3568819344552931
# Standard Deviation: 0.8158569393614284
# Q1: 1.0
# Q3: 1.0
# IQR: 0.0
# Lower Bound (Outlier): 1.0
# Upper Bound (Outlier): 1.0
# Number of Outliers: 72880
#
#
# Outlier statistics for column: Number_of_Vehicles
# Mean: 1.8290629373354157
# Standard Deviation: 0.7104766166622105
# Q1: 1.0
# Q3: 2.0
# IQR: 1.0
# Lower Bound (Outlier): -0.5
# Upper Bound (Outlier): 3.5
# ...

# %% [markdown]
# ### 3.1.3.1.2. Outlier Treatment: Non-Categorical Variables or Features
# #### 3.1.3.1.2.2. Normalization using Min-Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Assuming df_noncat_mdi_si is your DataFrame

# Define the columns to be normalized
columns_to_normalize = ['Latitude', 'Longitude', 'Number_of_Casualties', 'Number_of_Vehicles']

# Create a MinMaxScaler instance
mms = MinMaxScaler()

# Fit and transform the selected columns using MinMaxScaler
mms_fit = mms.fit_transform(df_noncat_mdi_si[columns_to_normalize])

# Create a DataFrame for the normalized values
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=[col + '_mmnorm' for col in columns_to_normalize])

# Concatenate the original DataFrame with the normalized values
df_noncat_mdi_mmn = pd.concat([df_noncat_mdi_si, df_noncat_minmax_norm], axis=1)

# Now df_noncat_mdi_mmn contains the original DataFrame with the selected variables normalized

# %%
df_noncat_mdi_mmn
# Out:
#          Latitude  Longitude  Number_of_Casualties  Number_of_Vehicles  \
# 0       51.512273  -0.201349                   1.0                 2.0
# 1       51.514399  -0.199248                  11.0                 2.0
# 2       51.486668  -0.179599                   1.0                 2.0
# 3       51.507804  -0.203110                   1.0                 2.0
# 4       51.482076  -0.173445                   1.0                 2.0
# ...           ...        ...                   ...                 ...
# 307968  57.374005  -3.467828                   2.0                 1.0
# 307969  57.232273  -3.809281                   1.0                 1.0
# 307970  57.585044  -3.862727                   1.0                 3.0
# 307971  57.214898  -3.823997                   1.0                 2.0
# 307972  57.575210  -3.895673                   1.0                 1.0
#
#         Speed_limit  Latitude_mmnorm  Longitude_mmnorm  \
# 0              30.0         0.149555          0.788613
# ...

# %% [markdown]
# # Combining the final Dataset

# %%
# Assuming df_cat_mdt_code_le, df_cat_mdi_code_oe, and df_noncat_mdi_mmn are your DataFrames

# Columns from df_cat_mdt_code_le
cat_mdt_columns = ['Accident_Index', 'Accident Date', 'Junction_Control_code', 'Junction_Detail_code',
                   'Light_Conditions_code', 'Local_Authority_(District)_code', 'Carriageway_Hazards_code',
                   'Police_Force_code', 'Road_Surface_Conditions_code', 'Road_Type_code',
                   'Urban_or_Rural_Area_code', 'Weather_Conditions_code', 'Vehicle_Type_code','Time']

# Columns from df_cat_mdi_code_oe
cat_mdi_columns = ['Day_of_Week_code', 'Accident_Severity_code']

# Columns from df_noncat_mdi_mmn
noncat_mdi_columns = ['Latitude_mmnorm', 'Longitude_mmnorm', 'Number_of_Casualties_mmnorm',
                      'Number_of_Vehicles_mmnorm','Speed_limit']

# Concatenate the specified columns from different DataFrames
combined_df = pd.concat([df_cat_mdt_code_le[cat_mdt_columns], df_cat_mdi_code_oe[cat_mdi_columns],
                         df_noncat_mdi_mmn[noncat_mdi_columns]], axis=1)

# Now combined_df contains the specified columns from different DataFrames combined into a single DataFrame
combined_df
# Out:
#        Accident_Index Accident Date  Junction_Control_code  \
# 0       200901BS70001    01-01-2021                      4
# 1       200901BS70002    05-01-2021                      4
# 2       200901BS70003    04-01-2021                      4
# 3       200901BS70004    05-01-2021                      2
# 4       200901BS70005    06-01-2021                      2
# ...               ...           ...                    ...
# 307968  201091NM01760    18-02-2022                      3
# 307969  201091NM01881    21-02-2022                      3
# 307970  201091NM01935    23-02-2022                      4
# 307971  201091NM01964    23-02-2022                      4
# 307972  201091NM02142    28-02-2022                      4
#
#         Junction_Detail_code  Light_Conditions_code  \
# 0                          8                      4
# 1                          0                      4
# 2                          8                      4
# ...

# %% [markdown]
# ## 3.2 Data Analysis

# %% [markdown]
# ### 3.2.1.1. PO1 | PS1:: Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_2cluster = KMeans(n_clusters=2, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_2cluster_model = km_2cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_2cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [0 1 0 ... 0 1 1]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_2cluster = silhouette_score(combined_numeric, km_2cluster_model)
print("Silhouette Score:", sscore_km_2cluster)

# Calculate Davies-Bouldin score
dbscore_km_2cluster = davies_bouldin_score(combined_numeric, km_2cluster_model)
print("Davies-Bouldin Score:", dbscore_km_2cluster)
# Out:
# Silhouette Score: 0.02546637355129478
# Davies-Bouldin Score: 42.3738220531719

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_3cluster = KMeans(n_clusters=3, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_3cluster_model = km_3cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_3cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [2 0 2 ... 0 0 1]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_3cluster = silhouette_score(combined_numeric, km_3cluster_model)
print("Silhouette Score:", sscore_km_3cluster)

# Calculate Davies-Bouldin score
dbscore_km_3cluster = davies_bouldin_score(combined_numeric, km_3cluster_model)
print("Davies-Bouldin Score:", dbscore_km_3cluster)
# Out:
# Silhouette Score: 0.0005741600005830396
# Davies-Bouldin Score: 45.85307471096089

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_4cluster = KMeans(n_clusters=4, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_4cluster_model = km_4cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_4cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [0 3 0 ... 0 3 2]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_4cluster = silhouette_score(combined_numeric, km_4cluster_model)
print("Silhouette Score:", sscore_km_4cluster)

# Calculate Davies-Bouldin score
dbscore_km_4cluster = davies_bouldin_score(combined_numeric, km_4cluster_model)
print("Davies-Bouldin Score:", dbscore_km_4cluster)
# Out:
# Silhouette Score: 0.021430079094563816
# Davies-Bouldin Score: 25.51007321005486

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_5cluster = KMeans(n_clusters=5, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_5cluster_model = km_5cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_5cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [0 3 0 ... 3 3 1]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_5cluster = silhouette_score(combined_numeric, km_5cluster_model)
print("Silhouette Score:", sscore_km_5cluster)

# Calculate Davies-Bouldin score
dbscore_km_5cluster = davies_bouldin_score(combined_numeric, km_5cluster_model)
print("Davies-Bouldin Score:", dbscore_km_5cluster)
# Out:
# Silhouette Score: -0.025800628119926877
# Davies-Bouldin Score: 15.324547795941722

# %% [markdown]
# ## K=3 seems to be the most appropriate choice here

# %%
combined_subset_kmcluster = subset_data.copy()
combined_subset_kmcluster.reset_index(level=0, inplace=True, names='car_index')
combined_subset_kmcluster['cluster_number'] = km_3cluster_model
combined_subset_kmcluster.sort_values('cluster_number', inplace=True); combined_subset_kmcluster
# Out:
#         car_index  Light_Conditions_code  Weather_Conditions_code  \
# 153986     153986                      3                        1
# 50733       50733                      4                        1
# 50735       50735                      4                        1
# 50736       50736                      1                        1
# 175509     175509                      4                        3
# ...           ...                    ...                      ...
# 163146     163146                      4                        1
# 163147     163147                      4                        0
# 53906       53906                      4                        1
# 163176     163176                      4                        1
# 0               0                      4                        1
#
#         Road_Surface_Conditions_code  cluster_number
# 153986                             4               0
# 50733                              4               0
# ...

# %%
import matplotlib.pyplot as plt

# Assuming km_2cluster_model contains the cluster labels obtained from KMeans clustering

# Create scatter plots for each pair of variables
plt.figure(figsize=(15, 12))

# Define the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 3

# Iterate over each pair of variables
for i, var1 in enumerate(subset_data.columns[:-1]):
    for j, var2 in enumerate(subset_data.columns[i+1:]):
        # Calculate the subplot index
        subplot_index = i * (len(subset_data.columns) - 1) + j + 1

        # Ensure the subplot index is within the valid range
        if subplot_index <= num_rows * num_cols:
            plt.subplot(num_rows, num_cols, subplot_index)

            # Scatter plot for each cluster
            for cluster in range(3):  # Assuming 3 clusters
                plt.scatter(subset_data[km_3cluster_model == cluster][var1],
                            subset_data[km_3cluster_model == cluster][var2],
                            label=f'Cluster {cluster}')

            plt.xlabel(var1)
            plt.ylabel(var2)
            plt.legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-42-e67a1514b3ba>:33: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from scipy.stats import chi2_contingency

# Define the categorical variables for the Chi-square test
categorical_variables = ['Light_Conditions_code','Weather_Conditions_code','Road_Surface_Conditions_code']

# Perform Chi-square test for each categorical variable
for variable in categorical_variables:
    # Create contingency table
    contingency_table = pd.crosstab(subset_data[variable], km_3cluster_model)

    # Perform Chi-square test
    chi2_stat, p_val, _, _ = chi2_contingency(contingency_table)

    # Print results
    print(f"Chi-square test for {variable}:")
    print(f"Chi-square statistic: {chi2_stat}")
    print(f"P-value: {p_val}")
    print("")

    # Consider a significance level (e.g., 0.05) to determine if the variable distinguishes the clusters.
    if p_val < 0.05:
        print(f"The variable {variable} significantly distinguishes the clusters.")
    else:
        print(f"The variable {variable} does not significantly distinguish the clusters.")
    print("")
# Out:
# Chi-square test for Light_Conditions_code:
# Chi-square statistic: 15671.633854324291
# P-value: 0.0
#
# The variable Light_Conditions_code significantly distinguishes the clusters.
#
# Chi-square test for Weather_Conditions_code:
# Chi-square statistic: 342887.0420284526
# P-value: 0.0
#
# The variable Weather_Conditions_code significantly distinguishes the clusters.
#
# Chi-square test for Road_Surface_Conditions_code:
# Chi-square statistic: 326550.9468881368
# P-value: 0.0
#
# The variable Road_Surface_Conditions_code significantly distinguishes the clusters.

# %%
# !pip install memory_profiler

# %%
# Import the necessary libraries
from memory_profiler import memory_usage
from sklearn.cluster import KMeans
import time

# Define the function for clustering with varying k
def clustering_memory_usage(k):
    # Your clustering code here
    # For example:
    start_time = time.time()
    km_model = KMeans(n_clusters=k).fit(subset_data)
    end_time = time.time()
    execution_time = end_time - start_time
    return km_model, execution_time

# Define the values of k for which you want to measure memory usage
k_values = [2, 3, 4, 5]

# Iterate over each value of k and measure memory usage
for k in k_values:
    mem_usage = memory_usage((clustering_memory_usage, (k,), {}))
    model, exec_time = clustering_memory_usage(k)
    print('For k = %d, maximum memory usage: %s MB, execution time: %.6f seconds' % (k, max(mem_usage), exec_time))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For k = 2, maximum memory usage: 1011.86328125 MB, execution time: 1.286329 seconds
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from sklearn.cluster import KMeans

# Define the range of k values
k_values = [2, 3, 4, 5]

# Iterate over each k value
for k in k_values:
    # Initialize KMeans clustering algorithm
    kmeans = KMeans(n_clusters=k, random_state=42)

    # Fit the model and predict cluster labels
    cluster_labels = kmeans.fit_predict(subset_data)

    # Count the number of data points in each cluster
    cluster_sizes = []
    for cluster in range(k):
        size = len(cluster_labels[cluster_labels == cluster])
        cluster_sizes.append(size)

    # Print the cluster sizes for the current value of k
    print(f"Cluster sizes for k={k}: {cluster_sizes}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=2: [216456, 91517]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=3: [55143, 209078, 43752]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=4: [174573, 43649, 37436, 52315]
# ...

# %% [markdown]
# 2 cluster

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Road_Type_code', 'Urban_or_Rural_Area_code', 'Accident_Severity_code','Light_Conditions_code']]
# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_22cluster = KMeans(n_clusters=2, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_22cluster_model = km_22cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_22cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_22cluster = silhouette_score(combined_numeric, km_22cluster_model)
print("Silhouette Score:", sscore_km_22cluster)

# Calculate Davies-Bouldin score
dbscore_km_22cluster = davies_bouldin_score(combined_numeric, km_22cluster_model)
print("Davies-Bouldin Score:", dbscore_km_22cluster)
# Out:
# Silhouette Score: 0.23063166138520994
# Davies-Bouldin Score: 4.368843702967515

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Road_Type_code', 'Urban_or_Rural_Area_code', 'Accident_Severity_code','Light_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_33cluster = KMeans(n_clusters=3, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_33cluster_model = km_33cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_33cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [2 0 0 ... 0 0 2]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_33cluster = silhouette_score(combined_numeric, km_33cluster_model)
print("Silhouette Score:", sscore_km_33cluster)

# Calculate Davies-Bouldin score
dbscore_km_33cluster = davies_bouldin_score(combined_numeric, km_33cluster_model)
print("Davies-Bouldin Score:", dbscore_km_33cluster)
# Out:
# Silhouette Score: -0.005366294886769236
# Davies-Bouldin Score: 16.650587110763784

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Assuming combined_df is your DataFrame containing the variables for clustering

# Create a subset of your data containing the variables for clustering
subset_data = combined_df[['Road_Type_code', 'Urban_or_Rural_Area_code', 'Accident_Severity_code','Light_Conditions_code']]

# Initialize the k-means clustering algorithm
# You need to specify the number of clusters you want
km_44cluster = KMeans(n_clusters=4, init='random', random_state=222)

# Fit the k-means model and predict the cluster labels for each data point
km_44cluster_model = km_44cluster.fit_predict(subset_data)

# Print the cluster labels
print("Cluster Labels:", km_44cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster Labels: [3 0 0 ... 0 0 3]

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.preprocessing import LabelEncoder

# Drop non-numeric columns
combined_numeric = combined_df.drop(['Accident_Index', 'Accident Date'], axis=1)

# Encode categorical variables if needed
encoder = LabelEncoder()
for column in combined_numeric.select_dtypes(include=['object']).columns:
    combined_numeric[column] = encoder.fit_transform(combined_numeric[column])

# Calculate silhouette score
sscore_km_44cluster = silhouette_score(combined_numeric, km_44cluster_model)
print("Silhouette Score:", sscore_km_44cluster)

# Calculate Davies-Bouldin score
dbscore_km_44cluster = davies_bouldin_score(combined_numeric, km_44cluster_model)
print("Davies-Bouldin Score:", dbscore_km_44cluster)
# Out:
# Silhouette Score: -0.017176282224383874
# Davies-Bouldin Score: 21.195585822305148

# %% [markdown]
# ## k=3 seems most appropriate

# %%
combined_subset_kmcluster = subset_data.copy()
combined_subset_kmcluster.reset_index(level=0, inplace=True, names='car_index')
combined_subset_kmcluster['cluster_number'] = km_33cluster_model
combined_subset_kmcluster.sort_values('cluster_number', inplace=True); combined_subset_kmcluster
# Out:
#         car_index  Road_Type_code  Urban_or_Rural_Area_code  \
# 153986     153986               3                         0
# 167196     167196               3                         1
# 167197     167197               3                         1
# 167198     167198               3                         1
# 167199     167199               3                         1
# ...           ...             ...                       ...
# 189020     189020               0                         0
# 188982     188982               0                         0
# 188978     188978               1                         0
# 189049     189049               1                         1
# 307972     307972               0                         0
#
#         Accident_Severity_code  Light_Conditions_code  cluster_number
# 153986                     3.0                      3               0
# 167196                     3.0                      4               0
# ...

# %%
import matplotlib.pyplot as plt

# Assuming km_2cluster_model contains the cluster labels obtained from KMeans clustering

# Create scatter plots for each pair of variables
plt.figure(figsize=(15, 12))

# Define the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 3

# Iterate over each pair of variables
for i, var1 in enumerate(subset_data.columns[:-1]):
    for j, var2 in enumerate(subset_data.columns[i+1:]):
        # Calculate the subplot index
        subplot_index = i * (len(subset_data.columns) - 1) + j + 1

        # Ensure the subplot index is within the valid range
        if subplot_index <= num_rows * num_cols:
            plt.subplot(num_rows, num_cols, subplot_index)

            # Scatter plot for each cluster
            for cluster in range(3):  # Assuming 3 clusters
                plt.scatter(subset_data[km_33cluster_model == cluster][var1],
                            subset_data[km_33cluster_model == cluster][var2],
                            label=f'Cluster {cluster}')

            plt.xlabel(var1)
            plt.ylabel(var2)
            plt.legend()

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-61-296ef0d7321f>:33: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from scipy.stats import chi2_contingency

# Define the categorical variables for the Chi-square test
categorical_variables = ['Road_Type_code', 'Urban_or_Rural_Area_code', 'Accident_Severity_code','Light_Conditions_code']

# Perform Chi-square test for each categorical variable
for variable in categorical_variables:
    # Create contingency table
    contingency_table = pd.crosstab(subset_data[variable], km_33cluster_model)

    # Perform Chi-square test
    chi2_stat, p_val, _, _ = chi2_contingency(contingency_table)

    # Print results
    print(f"Chi-square test for {variable}:")
    print(f"Chi-square statistic: {chi2_stat}")
    print(f"P-value: {p_val}")
    print("")

    # Consider a significance level (e.g., 0.05) to determine if the variable distinguishes the clusters.
    if p_val < 0.05:
        print(f"The variable {variable} significantly distinguishes the clusters.")
    else:
        print(f"The variable {variable} does not significantly distinguish the clusters.")
    print("")
# Out:
# Chi-square test for Road_Type_code:
# Chi-square statistic: 241823.8144978556
# P-value: 0.0
#
# The variable Road_Type_code significantly distinguishes the clusters.
#
# Chi-square test for Urban_or_Rural_Area_code:
# Chi-square statistic: 9933.174437192747
# P-value: 0.0
#
# The variable Urban_or_Rural_Area_code significantly distinguishes the clusters.
#
# Chi-square test for Accident_Severity_code:
# Chi-square statistic: 218.87606282576135
# P-value: 1.8067987070374187e-44
#
# The variable Accident_Severity_code significantly distinguishes the clusters.
#
# Chi-square test for Light_Conditions_code:
# Chi-square statistic: 307399.03758044244
# P-value: 0.0
#
# The variable Light_Conditions_code significantly distinguishes the clusters.

# %%
from sklearn.cluster import KMeans

# Define the range of k values
k_values = [2, 3, 4]

# Iterate over each k value
for k in k_values:
    # Initialize KMeans clustering algorithm
    kmeans = KMeans(n_clusters=k, random_state=42)

    # Fit the model and predict cluster labels
    cluster_labels = kmeans.fit_predict(subset_data)

    # Count the number of data points in each cluster
    cluster_sizes = []
    for cluster in range(k):
        size = len(cluster_labels[cluster_labels == cluster])
        cluster_sizes.append(size)

    # Print the cluster sizes for the current value of k
    print(f"Cluster sizes for k={k}: {cluster_sizes}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=2: [243814, 64159]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=3: [40378, 203646, 63949]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Cluster sizes for k=4: [203646, 52663, 11496, 40168]

# %%
# Import the necessary libraries
from memory_profiler import memory_usage
from sklearn.cluster import KMeans
import time

# Define the function for clustering with varying k
def clustering_memory_usage(k):
    # Your clustering code here
    # For example:
    start_time = time.time()
    km_model = KMeans(n_clusters=k).fit(subset_data)
    end_time = time.time()
    execution_time = end_time - start_time
    return km_model, execution_time

# Define the values of k for which you want to measure memory usage
k_values = [2, 3, 4]

# Iterate over each value of k and measure memory usage
for k in k_values:
    mem_usage = memory_usage((clustering_memory_usage, (k,), {}))
    model, exec_time = clustering_memory_usage(k)
    print('For k = %d, maximum memory usage: %s MB, execution time: %.6f seconds' % (k, max(mem_usage), exec_time))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# For k = 2, maximum memory usage: 1016.90234375 MB, execution time: 1.105747 seconds
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
